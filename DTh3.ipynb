# %% [markdown]
# ## Многокритериальная задача
# #### Козловский А.А., гр. 2253

# %%
import numpy as np
import pandas as pd
import copy

# %%
def matrix_by_rows(matrix, right_rows):
    """
    Функция для построение новой матрицы по строкам
    
    matrix: изначальная матрица [np.array]
    right_rows: строки, которые надо включить в новую матрицу [np.array]
    
    returns: новую матрицу [np.array]
    """
    
    result = []
    for row in right_rows:
        if row != -1:
            result.append(matrix[row])
            
    result = np.array(result)
    return result

# %%
def compare_pareto(matrix, row_1, row_2, features, types_of_features):
    """
    Метод для определения доминирования одной альтернативы над другой по Парето
    
    matrix: матрица признаков
    row_1: 1 строка матрицы признаков
    row_2: 2 строка матрицы признаков
    features: рассматриваемые критерии [np.array]
    types_of_features: виды критериев (-1 - негативный, 1 - позитивные) [np.array]
    
    returns: True - если первая строка доминирует вторую по Парето, иначе - False 
    """
    
    result = False
    for i, feature in enumerate(features):
        if types_of_features[i] * row_1[feature] < types_of_features[i] * row_2[feature]:
            return False
        if row_1[feature] != row_2[feature]:
            result = True
            
    return result

# %%
def make_pareto_optimal(matrix, features, types_of_features):
    """
    Функция построение Парето-оптимального множества
    
    matrix: матрица признаков [np.array]
    features: рассматриваемые критерии [np.array]
    types_of_features: виды критериев (-1 - негативный, 1 - позитивные) [np.array]
    
    returns: новую матрицу признаков для оптимального множетсва [np.array]
    """
    
    right_rows = np.arange(0, matrix.shape[0], 1, dtype=int)
    for index_1, row_1 in enumerate(matrix):
        for index_2, row_2 in enumerate(matrix):
            if index_1 == index_2:
                continue
            if compare_pareto(matrix, row_1, row_2, features, types_of_features):
                right_rows[index_2] = -1
         
    return matrix_by_rows(matrix, right_rows)

# %%
def low_bounds_method(matrix, features, types_of_features, low_bounds):
    """
    Функция для сужения оптимального множества методом нижних границ
    
    matrix: матрица признаков [np.array]
    features: рассматриваемые критерии [np.array]
    types_of_features: виды критериев (-1 - негативный, 1 - позитивные) [np.array]
    low_bounds: нижние границы для соответствующих критерие [np.array]
    
    returns: новую матрицу признаков для оптимального множетсва [np.array]
    """
    
    matrix_pareto = make_pareto_optimal(matrix, features, types_of_features)
    right_rows = np.arange(0, matrix_pareto.shape[0], 1, dtype=int)
    
    for row_num, row in enumerate(matrix_pareto):
        for feature_num, feature in enumerate(features):
            if (types_of_features[feature_num] * row[feature] < 
                types_of_features[feature_num] * low_bounds[feature_num]):
                right_rows[row_num] = -1
                break
                   
    return matrix_by_rows(matrix_pareto, right_rows)

# %%
def suboptimization(matrix, features, types_of_features, low_bounds, main_feature):
    """
    Функция для нахождения оптимального множества альтернатив с помощью
    субоптимизации
    
    matrix: матрица признаков [np.array]
    features: рассматриваемые критерии [np.array]
    types_of_features: виды критериев (-1 - негативный, 1 - позитивные) [np.array]
    low_bounds: нижние границы для соответствующих критерие [np.array]
    main_feature: главный критерий
    
    returns: новую матрицу признаков для оптимального множетсва [np.array]
    """
    
        
    
    right_rows = np.arange(0, matrix.shape[0], 1, dtype=int)
    for row_num, row in enumerate(matrix):
        for feature_num, feature in enumerate(features):
            if feature_num == main_feature:
                continue
            if (types_of_features[feature_num] * row[feature] < 
                types_of_features[feature_num] * low_bounds[feature_num]):
                right_rows[row_num] = -1
                break
             
    main_feature_matrix = matrix_by_rows(matrix, right_rows)
    right_rows = np.arange(0, main_feature_matrix.shape[0], 1, dtype=int)
    
    max_value = (types_of_features[main_feature] * 
        np.max(main_feature_matrix.T[features[main_feature]] * types_of_features[main_feature]))
    
    result = []
    for i, row in enumerate(main_feature_matrix):
        if row[features[main_feature]] == max_value:
            result.append(row)

    return result

# %%
def lexicographical_optimization(matrix, features, types_of_features):
    """
    Функция для лексикографической оптимизации
    
    matrix: матрица признаков [np.array]
    features: рассматриваемые критерии [np.array]
    types_of_features: виды критериев (-1 - негативный, 1 - позитивные) [np.array]
    
    returns: новую матрицу признаков для оптимального множетсва [np.array]
    """
    
    matrix_copy = matrix.copy()
    for feature_num, feature in enumerate(features):
        result = []
        max_value = (types_of_features[feature_num] * 
                    np.max(matrix_copy.T[feature] * types_of_features[feature_num]))
        for row in matrix_copy:
            if row[feature] == max_value:
                result.append(row)
                
        matrix_copy = np.array(result)
        if matrix_copy.shape[0] == 1:
            break
            
    return result

# %%
def general_feature_optimization(matrix, features, types_of_features, weights):
    """
    Функция для построения оптимального множества по обобщенному критерию
    
    matrix: матрица признаков [np.array]
    features: рассматриваемые критерии [np.array]
    types_of_features: виды критериев (-1 - негативный, 1 - позитивные) [np.array]
    weights: веса для построения обощенного критерия [np.array]
    
    returns: новую матрицу признаков для оптимального множетсва [np.array]
    """
    
    matrix_copy = matrix.copy()
    # Нормализуем значения признаков
    for feature in features:
        matrix_copy.T[feature] /= np.max(matrix_copy.T[feature] - np.min(matrix_copy.T[feature]))
        
    general_features = np.zeros(matrix_copy.shape[0])
    for index, general_feature in enumerate(general_features):
        for feature_num, feature in enumerate(features):
            general_features[index] += (matrix_copy[index][feature] * 
                               weights[feature_num] * types_of_features[feature_num]) 
            
    right_rows = np.argwhere(general_features == np.max(general_features))
    result = np.zeros((right_rows.shape[0], matrix_copy.shape[1]), dtype=object)
    for index, result_elemnt in enumerate(result):
        result[index] = matrix[right_rows[index]]
        
    return result

# %% [markdown]
# ### Решение многокритериальной задачи
# #### Подготовка данных
# Подготовим данные для решения задачи. Для этого возьмем датасет с книгами, подготовленный в предыдущем задании.
# Обозначим три критерия, по которым будет решаться многокритериальная задача. В нашем случае это будут: цена, рейтинг, количество оценок.

# %%
data = pd.read_csv('full_dataset3.csv')
matrix = data.to_numpy()
features = [-1, -2, -3]

# %% [markdown]
# ### Формирование множества Парето
# Сформируем множество Парето по трем выбранным критериям и датасету

# %%
matrix_pareto = make_pareto_optimal(matrix, features, [1, 1, -1])
pareto_df = pd.DataFrame(columns=data.columns, data=matrix_pareto)

# %%
pareto_df
# Out:
#                                                  name  \
# 0                                              Пётр I
# 1   Грокаем алгоритмы. Иллюстрированное пособие дл...
# 2                                   Компьютерные сети
# 3   Идеальный программист. Как стать профессионало...
# 4                    Современные операционные системы
# 5   Дизайн персонажей. Концепт-арт для комиксов, в...
# 6        Смартфон для тех, кто ни бум-бум в телефонах
# 7       Планшет для тех, кто ни бум-бум в компьютерах
# 8          Чистый код. Создание, анализ и рефакторинг
# 9                                   Компьютерные сети
# 10  Procreate. Учимся создавать шедевры на Ipad. Е...
# 11  Идеальный программист. Как стать профессионало...
# 12                            Программируем на Python
# 13      Все секреты Minecraft. Читы и командные блоки
# 14  Компьютер и Интернет с самых азов. Максимально...
# 15            Основы программирования на языке Python
# 16         Чистый код. Создание, анализ и рефакторинг
# 17                   Современные операционные системы
# 18  Дизайн персонажей. Концепт-арт для комиксов, в...
# 19  Procreate. Учимся создавать шедевры на Ipad. Е...
# 20            Основы программирования на языке Python
# 21                            Программируем на Python
# 22                                Статистика и котики
# 23      Ноутбук для тех, кто ни бум-бум в компьютерах
#
#                                                author  \
# 0     Новичкова Елена, Ратина Анна, Бунтман Екатерина
# 1                                     Бхаргава Адитья
# 2                     Таненбаум Эндрю, Уэзеролл Дэвид
# 3                                    Мартин Роберт С.
# 4                        Таненбаум Эндрю, Бос Херберт
# 5                  Кэттиш Анна, Че Тата, Смирнов Иван
# 6                            Левина Любовь Тимофеевна
# 7                            Левина Любовь Тимофеевна
# 8                                    Мартин Роберт С.
# 9                     Таненбаум Эндрю, Уэзеролл Дэвид
# 10  Уличнэй Макс, Нассур Сэм, Стокарт Эвелин, Грюн...
# 11                                   Мартин Роберт С.
# 12                                       Доусон Майкл
# 13                                       Миллер Меган
# 14                                         Жуков Иван
# 15                   Златопольский Дмитрий Михайлович
# 16                                   Мартин Роберт С.
# 17                       Таненбаум Эндрю, Бос Херберт
# 18                 Кэттиш Анна, Че Тата, Смирнов Иван
# 19  Уличнэй Макс, Нассур Сэм, Стокарт Эвелин, Грюн...
# 20                   Златопольский Дмитрий Михайлович
# 21                                       Доусон Майкл
# 22                                  Савельев Владимир
# 23                           Левина Любовь Тимофеевна
#
#                                       translator           editor  publisher  \
# 0                                            NaN  Новичкова Елена   Лабиринт
# 1                                     Матвеев Е.       Римицан Н.      Питер
# 2                                  Гребеньков А.     Сергиенко Ю.      Питер
# 3                                     Матвеев Е.     Сергиенко Ю.      Питер
# 4   Леонтьева А. В., Малышева М., Вильчинский Н.     Сергиенко Ю.      Питер
# 5                                    Семенова Д.              NaN      Питер
# 6                                            NaN              NaN        АСТ
# 7                                            NaN     Максимова О.        АСТ
# 8                                     Матвеев Е.     Сергиенко Ю.      Питер
# 9                                  Гребеньков А.     Сергиенко Ю.      Питер
# 10                                   Стеблева О.       Апалина А.    Бомбора
# 11                                    Матвеев Е.     Сергиенко Ю.      Питер
# 12                                           NaN       Гринчик Н.      Питер
# 13                                 Райтман М. А.       Иванова В.    Бомбора
# 14                                           NaN              NaN        АСТ
# 15                                           NaN     Мовчан Д. А.  ДМК-Пресс
# 16                                    Матвеев Е.     Сергиенко Ю.      Питер
# 17  Леонтьева А. В., Малышева М., Вильчинский Н.     Сергиенко Ю.      Питер
# 18                                   Семенова Д.              NaN      Питер
# 19                                   Стеблева О.       Апалина А.    Бомбора
# 20                                           NaN     Мовчан Д. А.  ДМК-Пресс
# 21                                           NaN       Гринчик Н.      Питер
# 22                                           NaN      Кольцова В.        АСТ
# 23                                           NaN              NaN        АСТ
#
#                                genre  \
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
# 5                                NaN
# 6                                NaN
# 7                                NaN
# 8                                NaN
# 9                                NaN
# 10                               NaN
# 11                               NaN
# 12                               NaN
# 13  Артбуки. Игровые миры. Вселенные
# 14                               NaN
# 15                               NaN
# 16                               NaN
# 17                               NaN
# 18                               NaN
# 19                               NaN
# 20                               NaN
# 21                               NaN
# 22  Машинное обучение. Анализ данных
# 23                               NaN
#
#                                       series articul               isbn  \
# 0          Детская художественная литература  507700  978-5-17-134106-0
# 1                    Библиотека программиста  571060  978-5-17-134106-0
# 2                  Классика computer science  310025  978-5-17-134106-0
# 3                                        NaN  643363  978-5-17-134106-0
# 4                  Классика computer science  485463  978-5-17-134106-0
# 5         Компьютерная графика и мультимедиа  780884  978-5-17-134106-0
# 6               Энциклопедия ржавого чайника  778712  978-5-17-134106-0
# 7               Энциклопедия ржавого чайника  775374  978-5-17-134106-0
# 8                                        NaN  642466  978-5-17-134106-0
# 9                  Классика computer science  310025  978-5-17-134106-0
# 10  Учимся рисовать на компьютере и планшете  773508  978-5-17-134106-0
# 11                                       NaN  643363  978-5-17-134106-0
# 12                                       NaN  311244  978-5-17-134106-0
# 13                                 Minecraft  590450  978-5-17-134106-0
# 14                   Современный самоучитель  758201  978-5-17-134106-0
# 15                                       NaN  668926  978-5-17-134106-0
# 16                                       NaN  642466  978-5-17-134106-0
# 17                 Классика computer science  485463  978-5-17-134106-0
# 18        Компьютерная графика и мультимедиа  780884  978-5-17-134106-0
# 19  Учимся рисовать на компьютере и планшете  773508  978-5-17-134106-0
# 20                                       NaN  668926  978-5-17-134106-0
# 21                                       NaN  311244  978-5-17-134106-0
# 22                     Звезда Рунета. Бизнес  638687  978-5-17-134106-0
# 23              Энциклопедия ржавого чайника  786458  978-5-17-134106-0
#
#    pages2 weight buying-price-val-number  rate count-marks-label
# 0    2820   1200                    3680   7.8               327
# 1     288    376                    1024  8.89                44
# 2     960   1344                    2312  9.47                40
# 3     224    300                     845    10                10
# 4    1120   1550                    2178  9.48                21
# 5     272    942                    2837  9.56                16
# 6     208    248                     304     0                 0
# 7     224    266                     304     0                 0
# 8     464    600                     921  9.07                14
# 9     960   1344                    2312  9.47                40
# 10    216   1108                    1340  9.57                14
# 11    224    300                     845    10                10
# 12    416    536                    1393  9.11                44
# 13  12870    340                     450   8.5                18
# 14    352    342                     385    10                 1
# 15    396    390                     827  8.56                16
# 16    464    600                     921  9.07                14
# 17   1120   1550                    2178  9.48                21
# 18    272    942                    2837  9.56                16
# 19    216   1108                    1340  9.57                14
# 20    396    390                     827  8.56                16
# 21    416    536                    1393  9.11                44
# 22  19240    324                     598  8.27                26
# 23    224    266                     304     0                 0

# %% [markdown]
# ### Указание нижних границ критериев
# Воспользуемся вторым методом. Найдем множество Парето оптимальных альтернатив, а потом назначим нижние допустимые границы критериев, чтобы сформировать финальное множество

# %%
matrix_low_bound = low_bounds_method(matrix, features, [1, 1, -1], [10, 6.5, 2000])
low_bound_df = pd.DataFrame(columns=data.columns, data=matrix_low_bound)

# %%
low_bound_df
# Out:
#                                                  name  \
# 0   Грокаем алгоритмы. Иллюстрированное пособие дл...
# 1   Идеальный программист. Как стать профессионало...
# 2          Чистый код. Создание, анализ и рефакторинг
# 3   Procreate. Учимся создавать шедевры на Ipad. Е...
# 4   Идеальный программист. Как стать профессионало...
# 5                             Программируем на Python
# 6       Все секреты Minecraft. Читы и командные блоки
# 7             Основы программирования на языке Python
# 8          Чистый код. Создание, анализ и рефакторинг
# 9   Procreate. Учимся создавать шедевры на Ipad. Е...
# 10            Основы программирования на языке Python
# 11                            Программируем на Python
# 12                                Статистика и котики
#
#                                                author     translator  \
# 0                                     Бхаргава Адитья     Матвеев Е.
# 1                                    Мартин Роберт С.     Матвеев Е.
# 2                                    Мартин Роберт С.     Матвеев Е.
# 3   Уличнэй Макс, Нассур Сэм, Стокарт Эвелин, Грюн...    Стеблева О.
# 4                                    Мартин Роберт С.     Матвеев Е.
# 5                                        Доусон Майкл            NaN
# 6                                        Миллер Меган  Райтман М. А.
# 7                    Златопольский Дмитрий Михайлович            NaN
# 8                                    Мартин Роберт С.     Матвеев Е.
# 9   Уличнэй Макс, Нассур Сэм, Стокарт Эвелин, Грюн...    Стеблева О.
# 10                   Златопольский Дмитрий Михайлович            NaN
# 11                                       Доусон Майкл            NaN
# 12                                  Савельев Владимир            NaN
#
#           editor  publisher                             genre  \
# 0     Римицан Н.      Питер                               NaN
# 1   Сергиенко Ю.      Питер                               NaN
# 2   Сергиенко Ю.      Питер                               NaN
# 3     Апалина А.    Бомбора                               NaN
# 4   Сергиенко Ю.      Питер                               NaN
# 5     Гринчик Н.      Питер                               NaN
# 6     Иванова В.    Бомбора  Артбуки. Игровые миры. Вселенные
# 7   Мовчан Д. А.  ДМК-Пресс                               NaN
# 8   Сергиенко Ю.      Питер                               NaN
# 9     Апалина А.    Бомбора                               NaN
# 10  Мовчан Д. А.  ДМК-Пресс                               NaN
# 11    Гринчик Н.      Питер                               NaN
# 12   Кольцова В.        АСТ  Машинное обучение. Анализ данных
#
#                                       series articul               isbn  \
# 0                    Библиотека программиста  571060  978-5-17-134106-0
# 1                                        NaN  643363  978-5-17-134106-0
# 2                                        NaN  642466  978-5-17-134106-0
# 3   Учимся рисовать на компьютере и планшете  773508  978-5-17-134106-0
# 4                                        NaN  643363  978-5-17-134106-0
# 5                                        NaN  311244  978-5-17-134106-0
# 6                                  Minecraft  590450  978-5-17-134106-0
# 7                                        NaN  668926  978-5-17-134106-0
# 8                                        NaN  642466  978-5-17-134106-0
# 9   Учимся рисовать на компьютере и планшете  773508  978-5-17-134106-0
# 10                                       NaN  668926  978-5-17-134106-0
# 11                                       NaN  311244  978-5-17-134106-0
# 12                     Звезда Рунета. Бизнес  638687  978-5-17-134106-0
#
#    pages2 weight buying-price-val-number  rate count-marks-label
# 0     288    376                    1024  8.89                44
# 1     224    300                     845    10                10
# 2     464    600                     921  9.07                14
# 3     216   1108                    1340  9.57                14
# 4     224    300                     845    10                10
# 5     416    536                    1393  9.11                44
# 6   12870    340                     450   8.5                18
# 7     396    390                     827  8.56                16
# 8     464    600                     921  9.07                14
# 9     216   1108                    1340  9.57                14
# 10    396    390                     827  8.56                16
# 11    416    536                    1393  9.11                44
# 12  19240    324                     598  8.27                26

# %% [markdown]
# ### Субоптимизация
# Выделим множество альтернатив, удовлетворяющих по нужным критериям нижним границам, и найдем максимум по главному критерию

# %%
matrix_sub = suboptimization(matrix, [-1, -2, -3], [1, 1, -1], [20, 5, 2000], 2)
sub_df = pd.DataFrame(columns=data.columns, data=matrix_sub)

# %%
sub_df
# Out:
#                   name             author  translator       editor publisher  \
# 0  Статистика и котики  Савельев Владимир         NaN  Кольцова В.       АСТ
#
#                               genre                 series  articul  \
# 0  Машинное обучение. Анализ данных  Звезда Рунета. Бизнес   638687
#
#                 isbn   pages2  weight  buying-price-val-number  rate  \
# 0  978-5-17-134106-0  19240.0   324.0                      598  8.27
#
#    count-marks-label
# 0                 26

# %% [markdown]
# ### Лексикографическая оптимизация
# Упорядочим критерии в порядке важности. Для этого просто укажем их в соответствующем порядке при передаче как параметр в нашу функцию. В порядке убывания важности наши критерии будут выглядеть так: рейтинг, цена, количество оценок

# %%
matrix_lex = lexicographical_optimization(matrix, [-2, -3, -1], [1, -1, 1])
lex_df = pd.DataFrame(columns=data.columns, data=matrix_lex)

# %%
lex_df
# Out:
#                                                 name      author  translator  \
# 0  Компьютер и Интернет с самых азов. Максимально...  Жуков Иван         NaN
#
#    editor publisher  genre                   series  articul  \
# 0     NaN       АСТ    NaN  Современный самоучитель   758201
#
#                 isbn  pages2  weight  buying-price-val-number  rate  \
# 0  978-5-17-134106-0   352.0   342.0                      385  10.0
#
#    count-marks-label
# 0                  1

# %% [markdown]
# ### Построение обощенного критерия
# Для построения обобщенного критерия будем использовать веса 0.1, 0.4, 0.5 для количества оценивших, рейтинга и цены соответственно.

# %%
matrix_general = general_feature_optimization(matrix, [-1, -2, -3], [1, 1, -1], [0.1, 0.4, 0.5])
general_df = pd.DataFrame(columns=data.columns, data=matrix_general)

# %%
general_df
# Out:
#                                                 name      author translator  \
# 0  Компьютер и Интернет с самых азов. Максимально...  Жуков Иван        NaN
#
#   editor publisher genre                   series articul               isbn  \
# 0    NaN       АСТ   NaN  Современный самоучитель  758201  978-5-17-134106-0
#
#   pages2 weight buying-price-val-number rate count-marks-label
# 0    352    342                     385   10                 1

# %%
# Out:
#                                                   name  \
# 0                                               Пётр I
# 1            Unity и C#. Геймдев от идеи до реализации
# 2    Грокаем алгоритмы. Иллюстрированное пособие дл...
# 3                                    Компьютерные сети
# 4      Интерфейс. Основы проектирования взаимодействия
# ..                                                 ...
# 259  Численные методы и программирование. Учебное п...
# 260  Web-программирование на JavaScript. Учебное по...
# 261  Технология разработки программного обеспечения...
# 262  Основы построения инфокоммуникационных сетей и...
# 263          Планшет. Умный самоучитель для начинающих
#
#                                                 author     translator  \
# 0      Новичкова Елена, Ратина Анна, Бунтман Екатерина            NaN
# 1                                  Бонд Джереми Гибсон     Киселев А.
# 2                                      Бхаргава Адитья     Матвеев Е.
# 3                      Таненбаум Эндрю, Уэзеролл Дэвид  Гребеньков А.
# 4    Купер Алан, Носсел Кристофер, Кронин Дэвид, Ре...     Матвеев Е.
# ..                                                 ...            ...
# 259                          Слабнов Виктор Дмитриевич            NaN
# 260                          Диков Андрей Валентинович            NaN
# 261                         Зубкова Татьяна Михайловна            NaN
# 262  Пуговкин Алексей Викторович, Покаместов Дмитри...            NaN
# 263                                          Лавров С.            NaN
#
#               editor publisher genre                                series  \
# 0    Новичкова Елена  Лабиринт   NaN     Детская художественная литература
# 1        Тульцева К.     Питер   NaN                    Для профессионалов
# 2         Римицан Н.     Питер   NaN               Библиотека программиста
# 3       Сергиенко Ю.     Питер   NaN             Классика computer science
# 4         Римицан Н.     Питер   NaN                    Для профессионалов
# ..               ...       ...   ...                                   ...
# 259              NaN      Лань   NaN  Компьютеры и программное обеспечение
# 260              NaN      Лань   NaN  Компьютеры и программное обеспечение
# 261              NaN      Лань   NaN  Компьютеры и программное обеспечение
# 262              NaN      Лань   NaN  Компьютеры и программное обеспечение
# 263              NaN       АСТ   NaN                     Умный самоучитель
#
#      articul               isbn  pages2  weight  buying-price-val-number  \
# 0     507700  978-5-17-134106-0  2820.0  1200.0                     3680
# 1     686355  978-5-17-134106-0   928.0  1190.0                     2975
# 2     571060  978-5-17-134106-0   288.0   376.0                     1024
# 3     310025  978-5-17-134106-0   960.0  1344.0                     2312
# 4     521205  978-5-17-134106-0   720.0   914.0                     2197
# ..       ...                ...     ...     ...                      ...
# 259   786067  978-5-17-134106-0   460.0   714.0                     3975
# 260   786072  978-5-17-134106-0   168.0   278.0                     1492
# 261   786076  978-5-17-134106-0   252.0   450.0                     2386
# 262   786078  978-5-17-134106-0   176.0   354.0                     1889
# 263   785687  978-5-17-134106-0   288.0   350.0                      433
#
#      rate  count-marks-label
# 0    7.80                327
# 1    9.70                 10
# 2    8.89                 44
# 3    9.47                 40
# 4    9.15                 13
# ..    ...                ...
# 259  0.00                  0
# 260  0.00                  0
# 261  0.00                  0
# 262  1.00                  1
# 263  0.00                  0
#
# [264 rows x 14 columns]
