# %% [markdown]
# ## ТПР. Задание 6.
# #### Козловский А.А., гр. 2253

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Равномерное распределение

# %%
uni_params = {
    'low': 0,
    'high': 1000,
    'size': 1000
}

uniform = np.random.uniform(**uni_params)

# %%
uni_params['mean'] = (uni_params['high'] - uni_params['low']) / 2
uni_params['std'] = (uni_params['high'] - uni_params['low']) / np.sqrt(12)

uni_params['actual_mean'] = uniform.mean()
uni_params['actual_std'] = uniform.std()

# %%
uni_params
# Out:
# {'low': 0,
#  'high': 1000,
#  'size': 1000,
#  'mean': 500.0,
#  'std': 288.6751345948129,
#  'actual_mean': 505.27257684618337,
#  'actual_std': 285.01511013148456}

# %%
plt.hist(uniform, 20)
plt.show()

# %%
sns.displot(uniform, kde=True)
plt.show()

# %% [markdown]
# ### Нормальное распределение

# %%
mu, sigma, quantity = 0, 4, 10000
normal = np.random.normal(mu, sigma, quantity)

# %%
normal_params = {
    'mean' : mu,
    'std': sigma,
    'quantity': quantity,
    'actual_mean': normal.mean(),
    'actual_std': normal.std(),
}

# %%
normal_params
# Out:
# {'mean': 0,
#  'std': 4,
#  'quantity': 10000,
#  'actual_mean': 0.0024352175870050873,
#  'actual_std': 4.011971587817477}

# %%
plt.hist(normal, 30)
plt.show()

# %%
sns.displot(normal, kde=True)
plt.show()

# %% [markdown]
# ### Распределение Пуассона

# %%
lamb = 5
poisson_params = {
    'mean': lamb,
    'std': np.sqrt(lamb),
    'lamb': lamb,
    'size': 10000
}

poisson = np.random.poisson(lamb, poisson_params['size'])

# %%
poisson_params['actual_mean'] = poisson.mean()
poisson_params['actual_std'] = poisson.std()

# %%
poisson_params
# Out:
# {'mean': 5,
#  'std': 2.23606797749979,
#  'lamb': 5,
#  'size': 10000,
#  'actual_mean': 4.9993,
#  'actual_std': 2.212035151167359}

# %%
plt.hist(poisson, 30)
plt.show()

# %%
sns.displot(poisson, kde=True)
plt.show()
